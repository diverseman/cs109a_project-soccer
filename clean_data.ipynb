# %%
import pandas as pd

# %%
fifa_19=pd.read_csv('data/players_19.csv')
fifa_19.head()
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     193080  https://sofifa.com/player/193080/david-de-gea-...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   33  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   31  1987-06-24
# 2          Neymar Jr        Neymar da Silva Santos Junior   26  1992-02-05
# 3             De Gea                David De Gea Quintana   27  1990-11-07
# 4       K. De Bruyne                      Kevin De Bruyne   27  1991-06-28
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %% [markdown]
# 是否存在空值和相关的一些问题

# %%
fifa_19.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   17770.000000  17770.000000  17770.000000  17770.000000  17770.000000
# mean   213797.776308     25.193922    181.253292     75.310917     66.240405
# std     29955.746535      4.651957      6.745892      7.080013      6.994104
# min       164.000000     16.000000    154.000000     50.000000     47.000000
# 25%    199803.000000     21.000000    176.000000     70.000000     62.000000
# 50%    221350.500000     25.000000    181.000000     75.000000     66.000000
# 75%    235967.750000     28.000000    186.000000     80.000000     71.000000
# max    246063.000000     45.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  17770.000000  1.777000e+04   17770.000000              17770.000000
# mean      71.382949  2.440756e+06    9956.162071                  1.117783
# ...

# %%
for ele in fifa_19.columns:
    print(f' column:{ele} \n type:{fifa_19[ele].dtype}, \n null values counts:{fifa_19[ele].isnull().sum()}')
    print()
# Out:
#  column:sofifa_id
#  type:int64,
#  null values counts:0
#
#  column:player_url
#  type:object,
#  null values counts:0
#
#  column:short_name
#  type:object,
#  null values counts:0
#
#  column:long_name
#  type:object,
#  null values counts:0
#
#  column:age
#  type:int64,
#  null values counts:0
#
#  column:dob
#  type:object,
#  null values counts:0
#
#  column:height_cm
#  type:int64,
#  null values counts:0
#
#  column:weight_kg
#  type:int64,
#  null values counts:0
#
#  column:nationality
#  type:object,
#  null values counts:0
#
#  column:club
#  type:object,
#  null values counts:0
#
#  column:overall
#  type:int64,
#  null values counts:0
#
#  column:potential
#  type:int64,
#  null values counts:0
#
#  column:value_eur
#  type:int64,
#  null values counts:0
#
#  column:wage_eur
#  type:int64,
#  null values counts:0
#
#  column:player_positions
#  type:object,
#  null values counts:0
#
#  column:preferred_foot
#  type:object,
#  null values counts:0
#
# ...

# %% [markdown]
# Type Transfer

# %%
index_start=list(fifa_19.columns).index('attacking_crossing')
index_end=list(fifa_19.columns).index('goalkeeping_reflexes')

# %%
import re 
fifa_19.iloc[:,index_start:index_end+1]=fifa_19.iloc[:,index_start:index_end+1].applymap(lambda x : int(x) if len(x)==2 else 
                                                                                         ( int(x.split('+')[0])+int(x.split('+')[1])
                                                                                          if x.__contains__('+')
                                                                                          else int(x.split('-')[0])-int(x.split('-')[1])
                                                                                          )                                                                                         
                                                                                         )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /mnt/d/BUAA_2/CS109Aproject/cs109a_project-soccer/clean_data.ipynb Cell 8 in <cell line: 2>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-18.04/mnt/d/BUAA_2/CS109Aproject/cs109a_project-soccer/clean_data.ipynb#ch0000014vscode-remote?line=0'>1</a> import re
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-18.04/mnt/d/BUAA_2/CS109Aproject/cs109a_project-soccer/clean_data.ipynb#ch0000014vscode-remote?line=1'>2</a> fifa_19.iloc[:,index_start:index_end+1]=fifa_19.iloc[:,index_start:index_end+1].applymap(lambda x : int(x) if len(x)==2 else
# ...

# %%
a=pd.DataFrame()
a=fifa_19.iloc[:,index_start:index_end+1].applymap(lambda x : int(x) if len(x)<=2 else 
                                                                                         ( int(x.split('-')[0])-int(x.split('-')[1])
                                                                                          if x.__contains__('-') 
                                                                                           else int(x.split('+')[0])+int(x.split('+')[1])                                                                               
                                                                                         ))

# %%
a
# Out:
#        attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 0                      84                   94                          89
# 1                      77                   95                          70
# 2                      79                   87                          62
# 3                      17                   13                          21
# 4                      93                   83                          55
# ...                   ...                  ...                         ...
# 17765                  31                   26                          49
# 17766                  37                   48                          30
# 17767                  40                   27                          45
# 17768                  39                   40                          45
# 17769                  37                   34                          49
#
# ...

# %%
#fifa_19.attacking_XXX,
(fifa_19.rs[0].split())
# Out:
# '91+3'

# %%
DROP_COLUMNS=['']

USE_FEATURE=[]

# %%
fifa_19.pace.describe()
# Out:
# count    15784.000000
# mean        67.815319
# std         11.329319
# min         24.000000
# 25%         61.000000
# 50%         69.000000
# 75%         75.000000
# max         96.000000
# Name: pace, dtype: float64

# %%
fifa_19.pace
# Out:
# 0        90.0
# 1        88.0
# 2        92.0
# 3         NaN
# 4        77.0
#          ...
# 17765    52.0
# 17766    64.0
# 17767    81.0
# 17768    63.0
# 17769    56.0
# Name: pace, Length: 17770, dtype: float64

# %% [markdown]
# 考虑变量之间的相关性
